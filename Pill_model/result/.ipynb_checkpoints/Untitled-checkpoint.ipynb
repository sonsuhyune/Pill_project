# %%
import os
ll = os.listdir()
ll
# Out:
# ['predict_and_gt.txt',
#  '.ipynb_checkpoints',
#  'before_crnn.txt',
#  'test_results.txt',
#  'log.txt',
#  'no_found.txt',
#  'test_results_temp.txt',
#  'Untitled.ipynb',
#  'test_results_nopill.txt',
#  'test_results_remove.txt',
#  'remove_new_east.txt',
#  'wrong_east',
#  'check_all.txt']

# %%
f = open("check_all.txt", 'r')
lines = f.readlines()
pred_list = []
gt_list = []
for line in lines:
    if len(line.split(' ')) == 1:
        pass
    
    
    elif line.split(' ')[0] == 'pred:':
        pred_num = len(line.split(' '))
        temp = []
        if pred_num == 2:
            temp.append(line.split(' ')[1][2:-3])
            #print(line.split(' ')[1][2:-3])
        elif pred_num == 3:
            temp.append(line.split(' ')[1][2:-2])
            temp.append(line.split(' ')[2][1:-3])
            
            #print(line.split(' ')[1][2:-2])
            #print(line.split(' ')[2][1:-3])
            
        elif pred_num == 4:
            temp.append(line.split(' ')[1][2:-2])
            temp.append(line.split(' ')[2][1:-2])
            temp.append(line.split(' ')[3][1:-3])
           
            
        else:
            print("---pred_num---: ",pred_num)
            print(line)
        pred_list.append(temp)
            
    elif line.split(' ')[0] == 'gt:':
        gt_num = len(line.split(' '))
        temp=[]
        if gt_num == 2:
            temp.append(line.split(' ')[1][2:-3])
        elif gt_num == 3:
            temp.append(line.split(' ')[1][2:-2])
            temp.append(line.split(' ')[2][1:-3])  
        elif gt_num == 4:
            temp.append(line.split(' ')[1][2:-2])
            temp.append(line.split(' ')[2][1:-2])
            temp.append(line.split(' ')[3][1:-3])    
        else:
            print("---gt_num---: ",gt_num)
            print(line)
        gt_list.append(temp)

# %%
print(pred_list)
# Out:
# [['Airtal'], ['|'], ['B|'], ['|'], ['Cr'], ['5'], ['HL300'], ['Airtal'], ['|'], ['B|'], ['|'], ['Cr'], ['5'], ['HL300'], ['CFT', '-'], ['ET'], ['ANG'], ['|5'], ['MMG'], ['ACIOS'], ['ADCX', '|'], ['33'], ['YH'], ['W'], ['AM', '|'], ['|'], ['r'], ['D'], ['5'], ['FEI', 'SK'], ['|'], ['TH'], ['JYM'], ['|10'], ['CX'], ['HN'], ['33'], ['BT'], ['1G'], ['ME7'], ['HRR'], ['HS'], ['HIR'], ['Z5'], ['|'], ['J2M'], ['VD'], ['FRT', 'SK'], ['|'], ['HN4'], ['G'], ['UV'], ['|'], ['33'], ['5'], ['HL300'], ['CX'], ['Airtal'], ['|r'], ['JYR'], ['JY'], ['BS'], ['FET', 'SK', '-'], ['4'], ['FFT', 'SK'], ['CFT'], ['G'], ['FET', 'SK'], ['HL300'], ['AM8'], ['FFT', 'SK', '|'], ['FET', 'SK'], ['|V', '|'], ['Airtal'], ['CX'], ['DK|', '|'], ['FEY'], ['|'], ['505'], ['|', '|'], ['BM', 'B3', '|'], ['ATL'], ['BM', 'B3', '|'], ['0'], ['|'], ['HIR'], ['ATY'], ['HIR'], ['|'], ['BM', 'B3', '|'], ['jr'], ['HL300'], ['|25'], ['2|5', '|'], ['H|M'], ['FET', 'SK', '|'], ['C'], ['D|W', '|'], ['|'], ['|'], ['80'], ['ME'], ['J2'], ['|'], ['FHI', '5K'], ['Airtal'], ['Z5'], ['B|W'], ['JYR'], ['H5'], ['|', 'AM'], ['CX', 'JY'], ['Z5'], ['DG', '33'], ['BS'], ['|'], ['|'], ['|5'], ['5K', 'FET'], ['010'], ['|'], ['|'], ['HS'], ['ATI'], ['M', '|'], ['LWG'], ['55'], ['FET', 'SK', '---'], ['ME'], ['ZY'], ['|'], ['RN>', '50'], ['|'], ['5'], ['CHT'], ['41'], ['|', '|'], ['B5'], ['D|C', '|'], ['|'], ['15'], ['33', 'DG'], ['G'], ['C10'], ['HL300'], ['|'], ['|'], ['ATV)'], ['ME1'], ['00', '38'], ['D|C', '|'], ['J'], ['D|'], ['HL300'], ['00', '33'], ['|'], ['|Y'], ['|'], ['|'], ['o|'], ['33', '00'], ['DS', '33'], ['|'], ['FRT', 'SK'], ['|'], ['|'], ['80'], ['HIR'], ['CX'], ['CX'], ['ME'], ['1G'], ['15', '|'], ['YH'], ['Airtal'], ['AT'], ['YMI'], ['-|'], ['|'], ['|'], ['CK', '|'], ['r'], ['1'], ['CX'], ['|'], ['L'], ['ME'], ['r'], ['JYL'], ['|'], ['(JY'], ['80'], ['5|', '|'], ['33'], ['CX'], ['5'], ['D-W', 'OF'], ['rr'], ['J1'], ['8X'], ['OK'], ['ATY'], ['|'], ['|', 'A1'], ['G'], ['|'], ['HJR'], ['8'], ['ACT05'], ['Airta', '|'], ['YH'], ['BM', 'B'], ['QS'], ['SK', 'FFT', '-'], ['UNCA'], ['33', '00'], ['|'], ['HN'], ['5'], ['J3'], ['AM'], ['FET', 'SK', '-'], ['20', 'JY'], ['-'], ['|'], ['15'], ['SEARLE'], ['|', '|'], ['140'], ['1000', '|'], ['|'], ['|'], ['|M'], ['|'], ['JN'], ['KH'], ['|'], ['s'], ['5D'], ['|'], ['008', '-'], ['B|80'], ['DX)'], ['ANA', '50'], ['A4'], ['|'], ['AR'], ['D|S', '|'], ['RS', 'JY'], ['CXL'], ['50)'], ['-', 'TG', 'AD'], ['XN'], ['|', '|'], ['|S', 'D'], ['ANA27'], ['|', '|'], ['JN'], ['KD'], ['|'], ['|', '||', '|'], ['|'], ['000'], ['|'], ['|N2'], ['20'], ['-'], ['|'], ['8300'], ['R5', 'H|'], ['GDOR', '|'], ['DXD'], ['|'], ['S)'], ['500/20'], ['CCCOR'], ['275)'], ['|'], ['|'], ['20'], ['|'], ['D', '|'], ['Y|CU'], ['|'], ['|'], ['CH'], ['C|N2', '|'], ['|'], ['AV'], ['5'], ['|', '|'], ['A', 'CGL'], ['B'], ['BK', '|'], ['D'], ['BD', '5', '-'], ['80'], ['|'], ['J'], ['|'], ['50', '|'], ['BX'], ['FA|', 'CH'], ['|UNITED'], ['CG'], ['M|'], ['|'], ['GDOR', '-'], ['|'], ['CNL'], ['|'], ['5'], ['S501'], ['|', '|'], ['|'], ['-', 'CICOR-1'], ['-'], ['CKD-'], ['|'], ['15'], ['|'], ['A|', '|'], ['AD'], ['J|8'], ['8'], ['|'], ['140', '|'], ['|'], ['AZ|'], ['140'], ['|'], ['|'], ['D|5', '|'], ['|', '|'], ['N|'], ['G4C'], ['||M'], ['CKD', '-'], ['|'], ['HGH', '|'], ['B|6'], ['||'], ['CNL'], ['A|M', '|'], ['S'], ['-', 'SR'], ['|'], ['1:'], ['A', 'CHZ'], ['(BK'], ['|'], ['|'], ['(5'], ['5'], ['OMP', 'H'], ['|66', '|'], ['|'], ['CNL'], ['JI', '|'], ['05'], ['E|N'], ['X|S', '|'], ['Y|'], ['DS'], ['D|S)'], ['SEARLE', '30'], ['D|'], ['JJ'], ['FE7', 'GS'], ['|', 'J'], ['500/20-'], ['-'], ['|'], ['|'], ['|', '|'], ['NI'], ['C'], ['|'], ['|'], ['|', 'C2'], ['K'], ['|', 'CICOR'], ['S|'], ['AV'], ['|'], ['1', '|'], ['CG', 'A'], ['|', 'CCCCROC'], ['CICORT'], ['V'], ['|', 'CG'], ['JY', 'RS'], ['KH'], ['T5'], ['N'], ['|'], ['AV'], ['50)'], ['H'], ['39|', 'HARLE'], ['|', 'H|'], ['CG', 'A'], ['CKDY'], ['s3b0'], ['|'], ['LJ'], ['RS', 'JY'], ['UNITED', '|'], ['4'], ['G|'], ['sib'], ['Cossac-L', '- ...

# %%
print(gt_list)
# Out:
# [['Alrtal'], ['OG', '33'], ['D-W', 'OFX'], ['FT'], ['T'], ['15'], ['EL300'], ['Alrtal'], ['OG', '33'], ['D-W', 'OFX'], ['FT'], ['T'], ['15'], ['EL300'], ['FT'], ['MET'], ['AMG'], ['2|5'], ['AMG'], ['ACTOS'], ['ADCX'], ['OG', '33'], ['JY'], ['A|G'], ['AMG'], ['JY'], ['T'], ['D|C'], ['2|5'], ['FET', 'SK'], ['D|C'], ['HM'], ['JYP'], ['10'], ['JY', 'CX'], ['HM'], ['OG', '33'], ['MET'], ['16'], ['MET'], ['HTR'], ['ES'], ['HTR'], ['ZS'], ['HM'], ['JYP'], ['A|G'], ['FET', 'SK'], ['AMG'], ['HM'], ['16'], ['JYP'], ['J25'], ['OG', '33'], ['JY'], ['EL300'], ['JY', 'CX'], ['Alrtal'], ['T'], ['JYP'], ['JYP'], ['33', 'OG'], ['SK', 'FET'], ['JY'], ['SK', 'FET'], ['FT'], ['16'], ['SK', 'FET'], ['EL300'], ['AMG'], ['FET', 'SK'], ['SK', 'FET'], ['HM'], ['Alrtal'], ['JY', 'CX'], ['DK'], ['FET', 'SK'], ['FT'], ['5050'], ['J25'], ['BM', 'B3'], ['ATV'], ['BM', 'B3'], ['10'], ['OG', '33'], ['HTR'], ['ATV'], ['HTR'], ['10'], ['BM', 'B3'], ['T'], ['EL300'], ['J25'], ['2|5'], ['HM'], ['FET', 'SK'], ['JY', 'CX'], ['D|W'], ['DK'], ['JTA'], ['30'], ['MET'], ['J25'], ['ATV'], ['FET', 'SK'], ['Alrtal'], ['ZS'], ['D|W'], ['JYP'], ['ES'], ['AMG'], ['JY', 'CX'], ['ZS'], ['OG', '33'], ['ES'], ['J25'], ['J25'], ['2|5'], ['SK', 'FET'], ['10'], ['AMG'], ['JY'], ['ES'], ['ATV'], ['HM'], ['AMG'], ['ES'], ['FET', 'SK'], ['MET'], ['JY', 'CX'], ['JY'], ['ANT', '50'], ['YH'], ['15'], ['FT'], ['JY', 'CX'], ['JY', 'CX'], ['ES'], ['D|C'], ['T'], ['16'], ['OG', '33'], ['16'], ['10'], ['EL300'], ['JYP'], ['JY'], ['ATV'], ['MET'], ['OG', '33'], ['D|C'], ['JY'], ['D|W'], ['EL300'], ['OG', '33'], ['T'], ['YH'], ['16'], ['YH'], ['D-W', 'OFX'], ['OG', '33'], ['OG', '33'], ['10'], ['SK', 'FET'], ['D-W', 'OFX'], ['JYP'], ['30'], ['HTR'], ['JY', 'CX'], ['JY', 'CX'], ['MET'], ['16'], ['15'], ['JY'], ['Alrtal'], ['ATV'], ['HM'], ['JY', 'CX'], ['JY', 'CX'], ['JY'], ['DK'], ['T'], ['T'], ['JY', 'CX'], ['J25'], ['JY'], ['MET'], ['T'], ['JYP'], ['D-W', 'OFX'], ['JYP'], ['30'], ['D5'], ['OG', '33'], ['JY', 'CX'], ['15'], ['D-W', 'OFX'], ['T'], ['JY'], ['D-W', 'OFX'], ['T'], ['ATV'], ['AMG'], ['ATV'], ['FT'], ['YH'], ['HTR'], ['D-W', 'OFX'], ['ACTOS'], ['Alrtal'], ['JY'], ['BM', 'B3'], ['OG', '33'], ['SK', 'FET'], ['UDCA'], ['OG', '33'], ['BM', 'B3'], ['HM'], ['15'], ['OG', '33'], ['AMG'], ['FET', 'SK'], ['JY', '20'], ['|'], ['D'], ['C|N2'], ['SEARLE', '39'], ['|'], ['G40'], ['1000'], ['JY'], ['150'], ['B|M'], ['CICOR'], ['jw'], ['KH', '021'], ['D5'], ['JI', 'S300'], ['S1'], ['016'], ['008'], ['G|80'], ['DX'], ['ANT', '50'], ['AZ'], ['SL8'], ['JY', 'RS'], ['D|S'], ['JY', 'RS'], ['CXL', '4'], ['50'], ['AD', 'TG', '-'], ['ANT', '50'], ['|'], ['D'], ['ANA275'], ['Noltec10'], ['jw'], ['CKD'], ['D.W'], ['|'], ['CICOR'], ['1000'], ['G|80'], ['C|N2'], ['20', 'JY'], ['SR'], ['CICOR'], ['JI', 'S300'], ['R5'], ['GDOR'], ['DX'], ['20'], ['D|S'], ['500/20', 'Naxozol'], ['CICOR'], ['ANA275'], ['T'], ['75'], ['JY', '20'], ['1000'], ['D'], ['G|80'], ['SK'], ['FH|6'], ['A', 'CH'], ['C|N2'], ['JTA'], ['302', 'AV'], ['5', 'BD'], ['RS', 'JY'], ['A', 'CG'], ['FB'], ['BK'], ['012'], ['BD', '5'], ['G|80'], ['JY'], ['JY'], ['T|R'], ['ANT', '50'], ['DX', '05'], ['A', 'CH'], ['UNITED'], ['A', 'CG'], ['B|M'], ['T'], ['GDOR'], ['Y|H'], ['CNL', '5'], ['JY'], ['BD', '5'], ['S50'], ['5'], ['C|M'], ['CICOR'], ['AV'], ['CKD'], ['JI'], ['75'], ['ANA275'], ['AV'], ['TG', 'AD', '-'], ['G|80'], ['DX', '05'], ['5010'], ['J25'], ['B|M'], ['AZ'], ['G40'], ['750'], ['R5'], ['D|5'], ['|'], ['C|NI'], ['G40'], ['B|M'], ['CKD'], ['DX', '05'], ['HGH'], ['B|K'], ['|'], ['C|NI'], ['A|M'], ['S1'], ['SR'], ['Noltec10'], ['75'], ['A', 'CH'], ['BK'], ['B|K'], ['JI'], ['75'], ['S'], ['OMP'], ['FH|6'], ['S'], ['CNL', '5'], ['JY'], ['DX', '05'], ['C|NI'], ['X|S'], ['PC'], ['RS', 'JY'], ['D|S'], ['SEARLE', '39'], ['D|5'], ['DG'], ['GS', 'FE7'], ['C|N2'], ['500/20', 'Naxozol'], ['GDOR'], ['SK'], ['Cossac-L'], ['DX'], ['C|NI'], ['SR'], ['A', 'CH'], ['JY', 'RS'], ['C200'], ['SK'], ['CICOR'], ['D|S'], ['302', 'AV'], ['FH|6'], ['1'], ['A', 'CG'], [' ...

# %%
len(pred_list)
# Out:
# 934

# %%
len(gt_list)
# Out:
# 934

# %%
for pred, gt in zip(pred_list, gt_list):
    print(pred,gt)
# Out:
# ['Airtal'] ['Alrtal']
# ['|'] ['OG', '33']
# ['B|'] ['D-W', 'OFX']
# ['|'] ['FT']
# ['Cr'] ['T']
# ['5'] ['15']
# ['HL300'] ['EL300']
# ['Airtal'] ['Alrtal']
# ['|'] ['OG', '33']
# ['B|'] ['D-W', 'OFX']
# ['|'] ['FT']
# ['Cr'] ['T']
# ['5'] ['15']
# ['HL300'] ['EL300']
# ['CFT', '-'] ['FT']
# ['ET'] ['MET']
# ['ANG'] ['AMG']
# ['|5'] ['2|5']
# ['MMG'] ['AMG']
# ['ACIOS'] ['ACTOS']
# ['ADCX', '|'] ['ADCX']
# ['33'] ['OG', '33']
# ['YH'] ['JY']
# ['W'] ['A|G']
# ['AM', '|'] ['AMG']
# ['|'] ['JY']
# ['r'] ['T']
# ['D'] ['D|C']
# ['5'] ['2|5']
# ['FEI', 'SK'] ['FET', 'SK']
# ['|'] ['D|C']
# ['TH'] ['HM']
# ['JYM'] ['JYP']
# ['|10'] ['10']
# ['CX'] ['JY', 'CX']
# ['HN'] ['HM']
# ['33'] ['OG', '33']
# ['BT'] ['MET']
# ['1G'] ['16']
# ['ME7'] ['MET']
# ['HRR'] ['HTR']
# ['HS'] ['ES']
# ['HIR'] ['HTR']
# ['Z5'] ['ZS']
# ['|'] ['HM']
# ['J2M'] ['JYP']
# ['VD'] ['A|G']
# ['FRT', 'SK'] ['FET', 'SK']
# ['|'] ['AMG']
# ['HN4'] ['HM']
# ['G'] ['16']
# ['UV'] ['JYP']
# ['|'] ['J25']
# ['33'] ['OG', '33']
# ['5'] ['JY']
# ['HL300'] ['EL300']
# ['CX'] ['JY', 'CX']
# ['Airtal'] ['Alrtal']
# ['|r'] ['T']
# ['JYR'] ['JYP']
# ['JY'] ['JYP']
# ['BS'] ['33', 'OG']
# ['FET', 'SK', '-'] ['SK', 'FET']
# ['4'] ['JY']
# ['FFT', 'SK'] ['SK', 'FET']
# ['CFT'] ['FT']
# ['G'] ['16']
# ['FET', 'SK'] ['SK', 'FET']
# ['HL300'] ['EL300']
# ['AM8'] ['AMG']
# ['FFT', 'SK', '|'] ['FET', 'SK']
# ['FET', 'SK'] ['SK', 'FET']
# ['|V', '|'] ['HM']
# ['Airtal'] ['Alrtal']
# ['CX'] ['JY', 'CX']
# ['DK|', '|'] ['DK']
# ['FEY'] ['FET', 'SK']
# ['|'] ['FT']
# ['505'] ['5050']
# ['|', '|'] ['J25']
# ['BM', 'B3', '|'] ['BM', 'B3']
# ['ATL'] ['ATV']
# ['BM', 'B3', '|'] ['BM', 'B3']
# ['0'] ['10']
# ['|'] ['OG', '33']
# ['HIR'] ['HTR']
# ['ATY'] ['ATV']
# ['HIR'] ['HTR']
# ['|'] ['10']
# ['BM', 'B3', '|'] ['BM', 'B3']
# ['jr'] ['T']
# ['HL300'] ['EL300']
# ['|25'] ['J25']
# ['2|5', '|'] ['2|5']
# ['H|M'] ['HM']
# ['FET', 'SK', '|'] ['FET', 'SK']
# ['C'] ['JY', 'CX']
# ['D|W', '|'] ['D|W']
# ['|'] ['DK']
# ['|'] ['JTA']
# ['80'] ['30']
# ['ME'] ['MET']
# ['J2'] ['J25']
# ['|'] ['ATV']
# ['FHI', '5K'] ['FET', 'SK']
# ['Airtal'] ['Alrtal']
# ['Z5'] ['ZS']
# ['B|W'] ['D|W']
# ['JYR'] ['JYP']
# ['H5'] ['ES']
# ['|', 'AM'] ['AMG']
# ['CX', 'JY'] ['JY', 'CX']
# ['Z5'] ['ZS']
# ['DG', '33'] ['OG', '33']
# ['BS'] ['ES']
# ['|'] ['J25']
# ['|'] ['J25']
# ['|5'] ['2|5']
# ['5K', 'FET'] ['SK', 'FET']
# ['010'] ['10']
# ['|'] ['AMG']
# ['|'] ['JY']
# ['HS'] ['ES']
# ['ATI'] ['ATV']
# ['M', '|'] ['HM']
# ['LWG'] ['AMG']
# ['55'] ['ES']
# ['FET', 'SK', '---'] ['FET', 'SK']
# ['ME'] ['MET']
# ['ZY'] ['JY', 'CX']
# ['|'] ['JY']
# ['RN>', '50'] ['ANT', '50']
# ['|'] ['YH']
# ['5'] ['15']
# ['CHT'] ['FT']
# ['41'] ['JY', 'CX']
# ['|', '|'] ['JY', 'CX']
# ['B5'] ['ES']
# ['D|C', '|'] ['D|C']
# ['|'] ['T']
# ['15'] ['16']
# ['33', 'DG'] ['OG', '33']
# ['G'] ['16']
# ['C10'] ['10']
# ['HL300'] ['EL300']
# ['|'] ['JYP']
# ['|'] ['JY']
# ['ATV)'] ['ATV']
# ['ME1'] ['MET']
# ['00', '38'] ['OG', '33']
# ['D|C', '|'] ['D|C']
# ['J'] ['JY']
# ['D|'] ['D|W']
# ['HL300'] ['EL300']
# ['00', '33'] ['OG', '33']
# ['|'] ['T']
# ['|Y'] ['YH']
# ['|'] ['16']
# ['|'] ['YH']
# ['o|'] ['D-W', 'OFX']
# ['33', '00'] ['OG', '33']
# ['DS', '33'] ['OG', '33']
# ['|'] ['10']
# ['FRT', 'SK'] ['SK', 'FET']
# ['|'] ['D-W', 'OFX']
# ['|'] ['JYP']
# ['80'] ['30']
# ['HIR'] ['HTR']
# ['CX'] ['JY', 'CX']
# ['CX'] ['JY', 'CX']
# ['ME'] ['MET']
# ['1G'] ['16']
# ['15', '|'] ['15']
# ['YH'] ['JY']
# ['Airtal'] ['Alrtal']
# ['AT'] ['ATV']
# ['YMI'] ['HM']
# ['-|'] ['JY', 'CX']
# ['|'] ['JY', 'CX']
# ['|'] ['JY']
# ['CK', '|'] ['DK']
# ['r'] ['T']
# ['1'] ['T']
# ['CX'] ['JY', 'CX']
# ['|'] ['J25']
# ['L'] ['JY']
# ['ME'] ['MET']
# ['r'] ['T']
# ['JYL'] ['JYP']
# ['|'] ['D-W', 'OFX']
# ['(JY'] ['JYP']
# ['80'] ['30']
# ['5|', '|'] ['D5']
# ['33'] ['OG', '33']
# ['CX'] ['JY', 'CX']
# ['5'] ['15']
# ['D-W', 'OF'] ['D-W', 'OFX']
# ['rr'] ['T']
# ['J1'] ['JY']
# ['8X'] ['D-W', 'OFX']
# ['OK'] ['T']
# ['ATY'] ['ATV']
# ['|'] ['AMG']
# ['|', 'A1'] ['ATV']
# ['G'] ['FT']
# ['|'] ['YH']
# ['HJR'] ['HTR']
# ['8'] ['D-W', 'OFX']
# ['ACT05'] ['ACTOS']
# ['Airta', '|'] ['Alrtal']
# ['YH'] ['JY']
# ['BM', 'B'] ['BM', 'B3']
# ['QS'] ['OG', '33']
# ['SK', 'FFT', '-'] ['SK', 'FET']
# ['UNCA'] ['UDCA']
# ['33', '00'] ['OG', '33']
# ['|'] ['BM', 'B3']
# ['HN'] ['HM']
# ['5'] ['15']
# ['J3'] ['OG', '33']
# ['AM'] ['AMG']
# ['FET', 'SK', '-'] ['FET', 'SK']
# ['20', 'JY'] ['JY', '20']
# ['-'] ['|']
# ['|'] ['D']
# ['15'] ['C|N2']
# ['SEARLE'] ['SEARLE', '39']
# ['|', '|'] ['|']
# ['140'] ['G40']
# ['1000', '|'] ['1000']
# ['|'] ['JY']
# ['|'] ['150']
# ['|M'] ['B|M']
# ['|'] ['CICOR']
# ['JN'] ['jw']
# ['KH'] ['KH', '021']
# ['|'] ['D5']
# ['s'] ['JI', 'S300']
# ['5D'] ['S1']
# ['|'] ['016']
# ['008', '-'] ['008']
# ['B|80'] ['G|80']
# ['DX)'] ['DX']
# ['ANA', '50'] ['ANT', '50']
# ['A4'] ['AZ']
# ['|'] ['SL8']
# ['AR'] ['JY', 'RS']
# ['D|S', '|'] ['D|S']
# ['RS', 'JY'] ['JY', 'RS']
# ['CXL'] ['CXL', '4']
# ['50)'] ['50']
# ['-', 'TG', 'AD'] ['AD', 'TG', '-']
# ['XN'] ['ANT', '50']
# ['|', '|'] ['|']
# ['|S', 'D'] ['D']
# ['ANA27'] ['ANA275']
# ['|', '|'] ['Noltec10']
# ['JN'] ['jw']
# ['KD'] ['CKD']
# ['|'] ['D.W']
# ['|', '||', '|'] ['|']
# ['|'] ['CICOR']
# ['000'] ['1000']
# ['|'] ['G|80']
# ['|N2'] ['C|N2']
# ['20'] ['20', 'JY']
# ['-'] ['SR']
# ['|'] ['CICOR']
# ['8300'] ['JI', 'S300']
# ['R5', 'H|'] ['R5']
# ['GDOR', '|'] ['GDOR']
# ['DXD'] ['DX']
# ['|'] ['20']
# ['S)'] ['D|S']
# ['500/20'] ['500/20', 'Naxozol']
# ['CCCOR'] ['CICOR']
# ['275)'] ['ANA275']
# ['|'] ['T']
# ['|'] ['75']
# ['20'] ['JY', '20']
# ['|'] ['1000']
# ['D', '|'] ['D']
# ['Y|CU'] ['G|80']
# ['|'] ['SK']
# ['|'] ['FH|6']
# ['CH'] ['A', 'CH']
# ['C|N2', '|'] ['C|N2']
# ['|'] ['JTA']
# ['AV'] ['302', 'AV']
# ['5'] ['5', 'BD']
# ['|', '|'] ['RS', 'JY']
# ['A', 'CGL'] ['A', 'CG']
# ['B'] ['FB']
# ['BK', '|'] ['BK']
# ['D'] ['012']
# ['BD', '5', '-'] ['BD', '5']
# ['80'] ['G|80']
# ['|'] ['JY']
# ['J'] ['JY']
# ['|'] ['T|R']
# ['50', '|'] ['ANT', '50']
# ['BX'] ['DX', '05']
# ['FA|', 'CH'] ['A', 'CH']
# ['|UNITED'] ['UNITED']
# ['CG'] ['A', 'CG']
# ['M|'] ['B|M']
# ['|'] ['T']
# ['GDOR', '-'] ['GDOR']
# ['|'] ['Y|H']
# ['CNL'] ['CNL', '5']
# ['|'] ['JY']
# ['5'] ['BD', '5']
# ['S501'] ['S50']
# ['|', '|'] ['5']
# ['|'] ['C|M']
# ['-', 'CICOR-1'] ['CICOR']
# ['-'] ['AV']
# ['CKD-'] ['CKD']
# ['|'] ['JI']
# ['15'] ['75']
# ['|'] ['ANA275']
# ['A|', '|'] ['AV']
# ['AD'] ['TG', 'AD', '-']
# ['J|8'] ['G|80']
# ['8'] ['DX', '05']
# ['|'] ['5010']
# ['140', '|'] ['J25']
# ['|'] ['B|M']
# ['AZ|'] ['AZ']
# ['140'] ['G40']
# ['|'] ['750']
# ['|'] ['R5']
# ['D|5', '|'] ['D|5']
# ['|', '|'] ['|']
# ['N|'] ['C|NI']
# ['G4C'] ['G40']
# ['||M'] ['B|M']
# ['CKD', '-'] ['CKD']
# ['|'] ['DX', '05']
# ['HGH', '|'] ['HGH']
# ['B|6'] ['B|K']
# ['||'] ['|']
# ['CNL'] ['C|NI']
# ['A|M', '|'] ['A|M']
# ['S'] ['S1']
# ['-', 'SR'] ['SR']
# ['|'] ['Noltec10']
# ['1:'] ['75']
# ['A', 'CHZ'] ['A', 'CH']
# ['(BK'] ['BK']
# ['|'] ['B|K']
# ['|'] ['JI']
# ['(5'] ['75']
# ['5'] ['S']
# ['OMP', 'H'] ['OMP']
# ['|66', '|'] ['FH|6']
# ['|'] ['S']
# ['CNL'] ['CNL', '5']
# ['JI', '|'] ['JY']
# ['05'] ['DX', '05']
# ['E|N'] ['C|NI']
# ['X|S', '|'] ['X|S']
# ['Y|'] ['PC']
# ['DS'] ['RS', 'JY']
# ['D|S)'] ['D|S']
# ['SEARLE', '30'] ['SEARLE', '39']
# ['D|'] ['D|5']
# ['JJ'] ['DG']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|', 'J'] ['C|N2']
# ['500/20-'] ['500/20', 'Naxozol']
# ['-'] ['GDOR']
# ['|'] ['SK']
# ['|'] ['Cossac-L']
# ['|', '|'] ['DX']
# ['NI'] ['C|NI']
# ['C'] ['SR']
# ['|'] ['A', 'CH']
# ['|'] ['JY', 'RS']
# ['|', 'C2'] ['C200']
# ['K'] ['SK']
# ['|', 'CICOR'] ['CICOR']
# ['S|'] ['D|S']
# ['AV'] ['302', 'AV']
# ['|'] ['FH|6']
# ['1', '|'] ['1']
# ['CG', 'A'] ['A', 'CG']
# ['|', 'CCCCROC'] ['CICOR']
# ['CICORT'] ['CICOR']
# ['V'] ['LV']
# ['|', 'CG'] ['CG']
# ['JY', 'RS'] ['RS', 'JY']
# ['KH'] ['KH', '021']
# ['T5'] ['MTS']
# ['N'] ['NVR']
# ['|'] ['H|3']
# ['AV'] ['302', 'AV']
# ['50)'] ['50']
# ['H'] ['Y|H']
# ['39|', 'HARLE'] ['SEARLE', '39']
# ['|', 'H|'] ['AV']
# ['CG', 'A'] ['A', 'CG']
# ['CKDY'] ['CKD']
# ['s3b0'] ['JI', 'S300']
# ['|'] ['016']
# ['LJ'] ['20']
# ['RS', 'JY'] ['JY', 'RS']
# ['UNITED', '|'] ['UNITED']
# ['4'] ['AZ']
# ['G|'] ['A|G']
# ['sib'] ['JI', 'S300']
# ['Cossac-L', '-'] ['Cossac-L']
# ['-'] ['GDOR']
# ['|'] ['CD']
# ['18'] ['018']
# ['|'] ['T']
# ['|', '(D5'] ['D5']
# ['125', '|'] ['125']
# ['A'] ['A', 'CH']
# ['|'] ['CG']
# ['A|'] ['NL']
# ['|'] ['2510']
# ['|'] ['SK']
# ['PA'] ['DX', '05']
# ['CH'] ['A', 'CH']
# ['|'] ['1000']
# ['|'] ['JY']
# ['C4'] ['T4']
# ['|'] ['500/20', 'Naxozol']
# ['KHL', '02V'] ['KH', '021']
# ['DC'] ['PC']
# ['|M'] ['B|M']
# ['C4'] ['T4']
# ['Y|'] ['ry']
# ['J'] ['JY']
# ['CC'] ['CKD']
# ['|'] ['500/20', 'Naxozol']
# ['RS', 'JY'] ['JY', 'RS']
# ['-V'] ['AV']
# ['|'] ['T|R']
# ['A4'] ['CICOR']
# ['4|3'] ['H|3']
# ['5'] ['R5']
# ['|'] ['1']
# ['|V', '|'] ['AV']
# ['H)'] ['Y|H']
# ['FE7', '|'] ['GS', 'FE7']
# ['CXL'] ['4', 'CXL']
# ['81', '|'] ['81']
# ['J'] ['JY']
# ['J1', '|'] ['J1']
# ['-', '-'] ['2510']
# ['|'] ['FH|6']
# ['JY', 'RS'] ['RS', 'JY']
# ['|4'] ['T4']
# ['C200', '|'] ['C200']
# ['A', 'CGL'] ['A', 'CG']
# ['KH'] ['KH', '021']
# ['1'] ['D5']
# ['S'] ['SR']
# ['s|b0'] ['JI', 'S300']
# ['|'] ['AV']
# ['|'] ['T']
# ['|'] ['JY', 'RS']
# ['-'] ['GDOR']
# ['|'] ['T']
# ['|', '010'] ['5010']
# ['RS', 'JY'] ['JY', 'RS']
# ['BG'] ['DX', '05']
# ['KH', '0HL'] ['KH', '021']
# ['|'] ['302', 'AV']
# ['5'] ['D|5']
# ['50'] ['G', '50']
# ['FE7', 'GS', '|'] ['GS', 'FE7']
# ['|'] ['CICOR']
# ['014'] ['012']
# ['S0'] ['G', '50']
# ['|'] ['JY']
# ['CX'] ['CXL', '4']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['50', '|'] ['50']
# ['2510', '|'] ['2510']
# ['|'] ['PC']
# ['(Hanmi'] ['Hanmi']
# ['|', '1S1'] ['S']
# ['-', 'AD', 'TG'] ['TG', 'AD', '-']
# ['|'] ['AV']
# ['BD', '5', '-'] ['BD', '5']
# ['BD', '5', '-'] ['5', 'BD']
# ['|'] ['LV']
# ['C'] ['C|NI']
# ['CG', 'A', '|'] ['A', 'CG']
# ['5'] ['5050']
# ['|'] ['CNL', '5']
# ['CNX', '50'] ['ANT', '50']
# ['5'] ['BD', '5']
# ['CH'] ['A', 'CH']
# ['|'] ['S50']
# ['H|S'] ['G|80']
# ['YG'] ['FB']
# ['|J'] ['J|Y']
# ['|'] ['D']
# ['SR', '|'] ['SR']
# ['|'] ['S1']
# ['-', '0|'] ['JY']
# ['|'] ['10']
# ['015', '-'] ['015']
# ['RS', 'JY'] ['JY', 'RS']
# ['s|b0'] ['JI', 'S300']
# ['|'] ['500/20', 'Naxozol']
# ['RS', 'JY'] ['JY', 'RS']
# ['C'] ['SR']
# ['DOR'] ['GDOR']
# ['|', '|CCCRR'] ['CICOR']
# ['|'] ['GDOR']
# ['B'] ['DX', '05']
# ['DD'] ['D']
# ['DU'] ['DG']
# ['JN'] ['jw']
# ['KK'] ['BK']
# ['Oltec10', '|'] ['Noltec10']
# ['B1'] ['B|M']
# ['|', 'D-W'] ['D-W']
# ['5010', '|'] ['5010']
# ['80', '|'] ['80']
# ['Naxozol'] ['Naxozol', '500/20']
# ['S|'] ['D|S']
# ['|', '(J25', '|'] ['J25']
# ['|5'] ['D|5']
# ['20', 'JY'] ['JY', '20']
# ['20'] ['20', 'JY']
# ['-', 'D'] ['D']
# ['AD'] ['A', 'CG']
# ['|', '|'] ['5']
# ['(K'] ['BK']
# ['-'] ['750']
# ['A', 'CHZ'] ['A', 'CH']
# ['axozol'] ['Naxozol', '500/20']
# ['|', 'D'] ['D|S']
# ['s50'] ['JI', 'S300']
# ['|'] ['T']
# ['Naxozol', '500/2'] ['Naxozol', '500/20']
# ['Naxozol'] ['Naxozol', '500/20']
# ['008', '|'] ['008']
# ['|||', '|'] ['|']
# ['DXD'] ['DX']
# ['|', '|'] ['10']
# ['56'] ['G', '50']
# ['0', '|'] ['G|80']
# ['C|L'] ['CNL', '5']
# ['|'] ['SR']
# ['R5', '|'] ['R5']
# ['|'] ['KH', '021']
# ['CK'] ['CKD']
# ['SEARLE', '30'] ['SEARLE', '39']
# ['JV'] ['jw']
# ['50%'] ['50']
# ['|', '|'] ['|']
# ['5'] ['D']
# ['GDOR'] ['GDOP']
# ['-'] ['500']
# ['|'] ['20']
# ['|', '|'] ['H|L']
# ['|'] ['D.W']
# ['-'] ['D5']
# ['|', '|'] ['KH', '021']
# ['|'] ['G|80']
# ['|NY'] ['C|NI']
# ['|', 'b0Y'] ['150']
# ['-'] ['20']
# ['GOF'] ['G|80']
# ['|'] ['C200']
# ['50'] ['750']
# ['AD', '-', 'TG'] ['AD', 'TG', '-']
# ['SEARLE', '30'] ['SEARLE', '39']
# ['RS'] ['RS', 'JY']
# ['S300'] ['JI', 'S300']
# ['R'] ['Y|H']
# ['G|8'] ['G|80']
# ['|'] ['S']
# ['SR', '|'] ['SR']
# ['|'] ['JY']
# ['CH', 'A'] ['A', 'CH']
# ['W'] ['D.W']
# ['CD'] ['|']
# ['|'] ['H|3']
# ['J'] ['LV']
# ['0', '|'] ['G', '50']
# ['-'] ['500']
# ['OSSAC-L'] ['Cossac-L']
# ['JG'] ['CG']
# ['H|S'] ['H|3']
# ['B1'] ['81']
# ['|'] ['Naxozol', '500/20']
# ['R'] ['81']
# ['JA'] ['75']
# ['4'] ['JY', '20']
# ['HA'] ['DX', '05']
# ['016', '-'] ['016']
# ['0/20', 'XOZOl'] ['Naxozol', '500/20']
# ['SEARLE', '38'] ['SEARLE', '39']
# ['D.W', '|'] ['D.W']
# ['|NI'] ['C|NI']
# ['AD'] ['TG', 'AD', '-']
# ['|'] ['H|3']
# ['588'] ['G|80']
# ['20', 'JY'] ['JY', '20']
# ['AZ|'] ['AZ']
# ['N1'] ['C|NI']
# ['4'] ['J25']
# ['|'] ['B|M']
# ['|'] ['JY']
# ['D.W', '|'] ['D.W']
# ['X'] ['DX']
# ['|'] ['D']
# ['-', '-'] ['5', 'BD']
# ['5|M'] ['C|M']
# ['||R', 'J'] ['T|R']
# ['154'] ['750']
# ['CXL'] ['CXL', '4']
# ['d0', '|'] ['A', 'CG']
# ['588'] ['G|80']
# ['|'] ['JY']
# ['AY'] ['A', 'CH']
# ['30', 'CLARLE'] ['SEARLE', '39']
# ['H|'] ['H|3']
# ['4'] ['4', 'CXL']
# ['|', '|'] ['|']
# ['|'] ['10']
# ['5'] ['5', 'BD']
# ['J4'] ['J25']
# ['H|'] ['|']
# ['|'] ['SR']
# ['|'] ['UT']
# ['Naxozol'] ['Naxozol', '500/20']
# ['Naxoz', '500/'] ['500/20', 'Naxozol']
# ['L'] ['NL']
# ['RS', 'S1'] ['RS', 'JY']
# ['MA|RYL'] ['AMA|RYL']
# ['C200', '|'] ['C200']
# ['JZ'] ['AZ']
# ['RS'] ['JY', 'RS']
# ['|'] ['T']
# ['5'] ['S']
# ['|'] ['A|M']
# ['|'] ['JI']
# ['G180'] ['G|80']
# ['|', 'SEARLE'] ['SEARLE', '39']
# ['-'] ['BK']
# ['|'] ['JY']
# ['|'] ['B|M']
# ['|', '1'] ['75']
# ['50', '|N'] ['ANT', '50']
# ['CX'] ['CXL', '4']
# ['AD', '-'] ['AD', 'TG', '-']
# ['5'] ['FH|6']
# ['|'] ['GDOR']
# ['|'] ['AV']
# ['|H'] ['|']
# ['DUF'] ['G|80']
# ['D.V'] ['D.W']
# ['500/20', '|'] ['500/20', 'Naxozol']
# ['-'] ['SK']
# ['|'] ['SR']
# ['RS', '|'] ['JY', 'RS']
# ['CD', 'LW'] ['CD']
# ['JLL', '|'] ['SL8']
# ['|'] ['UT']
# ['-'] ['GDOR']
# ['TA'] ['JTA']
# ['|', 'W'] ['D.W']
# ['|'] ['JI']
# ['ANA2'] ['ANA275']
# ['|'] ['GDOR']
# ['K'] ['SK']
# ['B'] ['B|K']
# ['|'] ['DX', '05']
# ['02'] ['302', 'AV']
# ['CG'] ['A', 'CG']
# ['T4', '|'] ['T4']
# ['S300'] ['JI', 'S300']
# ['D|S', '|'] ['D|S']
# ['|A', '|'] ['JTA']
# ['-', 'TG', 'AD'] ['TG', 'AD', '-']
# ['BD', '5', '-'] ['5', 'BD']
# ['|'] ['G|80']
# ['|'] ['JI']
# ['|'] ['SK']
# ['|', 'EARL'] ['SEARLE', '39']
# ['AD'] ['TG', 'AD', '-']
# ['|'] ['Cossac-L']
# ['|'] ['018']
# ['HGH', '|'] ['HGH']
# ['40', '|'] ['20', 'JY']
# ['4'] ['A', 'CH']
# ['DD'] ['D']
# ['C|M', '|'] ['C|M']
# ['NA2750'] ['ANA275']
# ['|5'] ['R5']
# ['RS', 'JY'] ['JY', 'RS']
# ['CX'] ['CXL', '4']
# ['|', '|'] ['H|3']
# ['6'] ['FH|6']
# ['N>'] ['ANT', '50']
# ['|'] ['SR']
# ['10'] ['G40']
# ['01'] ['81']
# ['|', 'B|'] ['B|K']
# ['CXL'] ['4', 'CXL']
# ['DC'] ['DG']
# ['Naxozo', '500/20'] ['Naxozol', '500/20']
# ['R5', 'HH|'] ['R5']
# ['|'] ['S']
# ['|', 'GA0'] ['G40']
# ['|'] ['H|3']
# ['0'] ['KH', '021']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['S300'] ['JI', 'S300']
# ['|'] ['Y|H']
# ['|'] ['CD']
# ['|'] ['KH', '021']
# ['|', '02L', 'KH'] ['KH', '021']
# ['J|'] ['JY']
# ['CXL'] ['4', 'CXL']
# ['|'] ['T']
# ['|'] ['DX', '05']
# ['D|S', '|'] ['D|S']
# ['8', '||'] ['81']
# ['20', 'JY'] ['JY', '20']
# ['H|6', '|'] ['FH|6']
# ['|N', '50'] ['ANT', '50']
# ['|'] ['AD', 'TG', '-']
# ['1'] ['T']
# ['10F', '|'] ['G40']
# ['|'] ['D']
# ['KH', '02V'] ['KH', '021']
# ['|'] ['Noltec10']
# ['A|'] ['A', 'CH']
# ['RS', 'JY'] ['JY', 'RS']
# ['DUU'] ['500']
# ['CNL'] ['CNL', '5']
# ['J|'] ['2510']
# ['5)'] ['75']
# ['D', '12'] ['012']
# ['CNL'] ['CNL', '5']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|'] ['H|3']
# ['s360'] ['JI', 'S300']
# ['CG', 'AX'] ['A', 'CG']
# ['|'] ['A', 'CG']
# ['1'] ['T']
# ['-', 'J'] ['D']
# ['A|M', '|'] ['A|M']
# ['T|R', '|', '|'] ['T|R']
# ['|', '6|'] ['FH|6']
# ['(1'] ['BK']
# ['JH'] ['OMP']
# ['|'] ['HGH']
# ['JK'] ['SK']
# ['|'] ['1']
# ['5'] ['BD', '5']
# ['4'] ['2']
# ['|'] ['D.W']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|N2'] ['C|N2']
# ['oltec10'] ['Noltec10']
# ['R|G'] ['FH|6']
# ['NL', '5'] ['CNL', '5']
# ['HW'] ['D-W']
# ['021'] ['KH', '021']
# ['K|'] ['B|K']
# ['016'] ['012']
# ['-', '|'] ['D']
# ['HGH', '|'] ['HGH']
# ['(BK)'] ['BK']
# ['|'] ['Y|H']
# ['|S'] ['|']
# ['|'] ['SK']
# ['JN'] ['jw']
# ['|5'] ['MTS']
# ['G80'] ['G|80']
# ['J4'] ['T4']
# ['H)'] ['Y|H']
# ['|'] ['SL8']
# ['5'] ['5', 'BD']
# ['5|', '|'] ['D|5']
# ['L'] ['NL']
# ['20', 'JY'] ['JY', '20']
# ['T|R', '|H|'] ['T|R']
# ['|'] ['JI']
# ['|'] ['A', 'CG']
# ['CXL'] ['CXL', '4']
# ['|'] ['SK']
# ['V'] ['AV']
# ['U1'] ['JI']
# ['(DG'] ['DG']
# ['D1'] ['D']
# ['|'] ['RS', 'JY']
# ['S500'] ['JI', 'S300']
# ['J'] ['JI']
# ['KD|', '|'] ['CKD']
# ['20', 'JY'] ['JY', '20']
# ['(016'] ['016']
# ['505'] ['5050']
# ['-'] ['750']
# ['50|'] ['150']
# ['|'] ['JY']
# ['|'] ['JI', 'S300']
# ['|'] ['S']
# ['1252'] ['125']
# ['39', 'HARLR'] ['SEARLE', '39']
# ['|'] ['H|L']
# ['CXL', '4'] ['4', 'CXL']
# ['RN>', '50'] ['ANT', '50']
# ['J|'] ['J|Y']
# ['|'] ['C']
# ['8500'] ['JI', 'S300']
# ['|44'] ['T4']
# ['15'] ['75']
# ['|'] ['A|M']
# ['5'] ['75']
# ['|'] ['S1']
# ['C', '50'] ['G', '50']
# ['|', 'Cr', '|'] ['CD']
# ['r'] ['D']
# ['|', '|'] ['AV']
# ['18', '|'] ['018']
# ['3K'] ['BK']
# ['|'] ['D-W']
# ['|'] ['T']
# ['H'] ['PC']
# ['-'] ['1000']
# ['1015'] ['015']
# ['Y|H', '|'] ['Y|H']
# ['|'] ['2']
# ['-'] ['JTA']
# ['R'] ['SR']
# ['|', '|'] ['|']
# ['|', 'J1'] ['2510']
# ['|'] ['10']
# ['HTS'] ['MTS']
# ['NT'] ['NVR']
# ['R|'] ['SR']
# ['|'] ['A|M']
# ['|'] ['D|5']
# ['|'] ['JY']
# ['CD', 'H|'] ['CD']
# ['15'] ['75']
# ['|'] ['JY']
# ['CG', '|'] ['A', 'CG']
# ['0'] ['DX', '05']
# ['RS'] ['R5']
# ['IOL'] ['125']
# ['|'] ['A', 'CH']
# ['-'] ['5010']
# ['|D.W', '|'] ['D.W']
# ['BD', '5', '-'] ['5', 'BD']
# ['|'] ['JY']
# ['CXL'] ['4', 'CXL']
# ['D,'] ['D.W']
# ['axozol'] ['Naxozol', '500/20']
# ['Y|H', '-'] ['Y|H']
# ['AD'] ['AD', 'TG', '-']
# ['S300'] ['JI', 'S300']
# ['|', '|'] ['|']
# ['NA275'] ['ANA275']
# ['4'] ['2']
# ['CKD', '-'] ['CKD']
# ['AD', '-', 'TG'] ['AD', 'TG', '-']
# ['XN>', '50'] ['ANT', '50']
# ['|'] ['D']
# ['|'] ['RS', 'JY']
# ['|'] ['5010']
# ['jUT'] ['GDOR']
# ['|'] ['JY']
# ['|', '|'] ['NL']
# ['H|'] ['B|M']
# ['C|2'] ['C|N2']
# ['-', 'TG', 'AD'] ['AD', 'TG', '-']
# ['0|'] ['150']
# ['550'] ['S50']
# ['HEARLH', '30'] ['SEARLE', '39']
# ['508', '-'] ['008']
# ['1', '|'] ['T']
# ['G'] ['D5']
# ['S300', '|', '|'] ['JI', 'S300']
# ['AV'] ['302', 'AV']
# ['|'] ['JY']
# ['|'] ['NVR']
# ['CNL'] ['CNL', '5']
# ['994'] ['952']
# ['150', '-'] ['150']
# ['|'] ['JY', 'RS']
# ['|', '|'] ['|']
# ['L'] ['LV']
# ['DX'] ['DX', '05']
# ['J|L'] ['JY']
# ['tec10'] ['Noltec10']
# ['H||'] ['B|M']
# ['|-'] ['A|G']
# ['>|N5'] ['C|N2']
# ['|'] ['B|M']
# ['CNL'] ['CNL', '5']
# ['|'] ['JY']
# ['JW'] ['D-W']
# ['10'] ['G40']
# ['|'] ['S1']
# ['RS', 'JY'] ['JY', 'RS']
# ['BD', '5'] ['5', 'BD']
# ['|'] ['2']
# ['|'] ['A', 'CH']
# ['U'] ['302', 'AV']
# ['|1'] ['S']
# ['-'] ['TG', 'AD', '-']
# ['|'] ['D']
# ['UV'] ['D-W']
# ['50', 'D'] ['G', '50']
# ['-'] ['MTS']
# ['|'] ['CICOR']
# ['|M'] ['B|M']
# ['|'] ['B|K']
# ['-', 'AD', 'TG'] ['TG', 'AD', '-']
# ['50', '|N'] ['ANT', '50']
# ['|K'] ['SK']
# ['4', 'J'] ['CXL', '4']
# ['C|S'] ['X|S']
# ['B'] ['FB']
# ['Cw'] ['D.W']
# ['C4'] ['T4']
# ['-', '|'] ['JY']
# ['JY', '|'] ['JY']
# ['|'] ['2510']
# ['|'] ['Noltec10']
# ['1000', '|'] ['1000']

# %%
for pred, gt in zip(pred_list, gt_list):
    if(len(pred) != len(gt)):
        continue
    else:
        print(pred,gt)
# Out:
# ['Airtal'] ['Alrtal']
# ['|'] ['FT']
# ['Cr'] ['T']
# ['5'] ['15']
# ['HL300'] ['EL300']
# ['Airtal'] ['Alrtal']
# ['|'] ['FT']
# ['Cr'] ['T']
# ['5'] ['15']
# ['HL300'] ['EL300']
# ['ET'] ['MET']
# ['ANG'] ['AMG']
# ['|5'] ['2|5']
# ['MMG'] ['AMG']
# ['ACIOS'] ['ACTOS']
# ['YH'] ['JY']
# ['W'] ['A|G']
# ['|'] ['JY']
# ['r'] ['T']
# ['D'] ['D|C']
# ['5'] ['2|5']
# ['FEI', 'SK'] ['FET', 'SK']
# ['|'] ['D|C']
# ['TH'] ['HM']
# ['JYM'] ['JYP']
# ['|10'] ['10']
# ['HN'] ['HM']
# ['BT'] ['MET']
# ['1G'] ['16']
# ['ME7'] ['MET']
# ['HRR'] ['HTR']
# ['HS'] ['ES']
# ['HIR'] ['HTR']
# ['Z5'] ['ZS']
# ['|'] ['HM']
# ['J2M'] ['JYP']
# ['VD'] ['A|G']
# ['FRT', 'SK'] ['FET', 'SK']
# ['|'] ['AMG']
# ['HN4'] ['HM']
# ['G'] ['16']
# ['UV'] ['JYP']
# ['|'] ['J25']
# ['5'] ['JY']
# ['HL300'] ['EL300']
# ['Airtal'] ['Alrtal']
# ['|r'] ['T']
# ['JYR'] ['JYP']
# ['JY'] ['JYP']
# ['4'] ['JY']
# ['FFT', 'SK'] ['SK', 'FET']
# ['CFT'] ['FT']
# ['G'] ['16']
# ['FET', 'SK'] ['SK', 'FET']
# ['HL300'] ['EL300']
# ['AM8'] ['AMG']
# ['FET', 'SK'] ['SK', 'FET']
# ['Airtal'] ['Alrtal']
# ['|'] ['FT']
# ['505'] ['5050']
# ['ATL'] ['ATV']
# ['0'] ['10']
# ['HIR'] ['HTR']
# ['ATY'] ['ATV']
# ['HIR'] ['HTR']
# ['|'] ['10']
# ['jr'] ['T']
# ['HL300'] ['EL300']
# ['|25'] ['J25']
# ['H|M'] ['HM']
# ['|'] ['DK']
# ['|'] ['JTA']
# ['80'] ['30']
# ['ME'] ['MET']
# ['J2'] ['J25']
# ['|'] ['ATV']
# ['FHI', '5K'] ['FET', 'SK']
# ['Airtal'] ['Alrtal']
# ['Z5'] ['ZS']
# ['B|W'] ['D|W']
# ['JYR'] ['JYP']
# ['H5'] ['ES']
# ['CX', 'JY'] ['JY', 'CX']
# ['Z5'] ['ZS']
# ['DG', '33'] ['OG', '33']
# ['BS'] ['ES']
# ['|'] ['J25']
# ['|'] ['J25']
# ['|5'] ['2|5']
# ['5K', 'FET'] ['SK', 'FET']
# ['010'] ['10']
# ['|'] ['AMG']
# ['|'] ['JY']
# ['HS'] ['ES']
# ['ATI'] ['ATV']
# ['LWG'] ['AMG']
# ['55'] ['ES']
# ['ME'] ['MET']
# ['|'] ['JY']
# ['RN>', '50'] ['ANT', '50']
# ['|'] ['YH']
# ['5'] ['15']
# ['CHT'] ['FT']
# ['|', '|'] ['JY', 'CX']
# ['B5'] ['ES']
# ['|'] ['T']
# ['15'] ['16']
# ['33', 'DG'] ['OG', '33']
# ['G'] ['16']
# ['C10'] ['10']
# ['HL300'] ['EL300']
# ['|'] ['JYP']
# ['|'] ['JY']
# ['ATV)'] ['ATV']
# ['ME1'] ['MET']
# ['00', '38'] ['OG', '33']
# ['J'] ['JY']
# ['D|'] ['D|W']
# ['HL300'] ['EL300']
# ['00', '33'] ['OG', '33']
# ['|'] ['T']
# ['|Y'] ['YH']
# ['|'] ['16']
# ['|'] ['YH']
# ['33', '00'] ['OG', '33']
# ['DS', '33'] ['OG', '33']
# ['|'] ['10']
# ['FRT', 'SK'] ['SK', 'FET']
# ['|'] ['JYP']
# ['80'] ['30']
# ['HIR'] ['HTR']
# ['ME'] ['MET']
# ['1G'] ['16']
# ['YH'] ['JY']
# ['Airtal'] ['Alrtal']
# ['AT'] ['ATV']
# ['YMI'] ['HM']
# ['|'] ['JY']
# ['r'] ['T']
# ['1'] ['T']
# ['|'] ['J25']
# ['L'] ['JY']
# ['ME'] ['MET']
# ['r'] ['T']
# ['JYL'] ['JYP']
# ['(JY'] ['JYP']
# ['80'] ['30']
# ['5'] ['15']
# ['D-W', 'OF'] ['D-W', 'OFX']
# ['rr'] ['T']
# ['J1'] ['JY']
# ['OK'] ['T']
# ['ATY'] ['ATV']
# ['|'] ['AMG']
# ['G'] ['FT']
# ['|'] ['YH']
# ['HJR'] ['HTR']
# ['ACT05'] ['ACTOS']
# ['YH'] ['JY']
# ['BM', 'B'] ['BM', 'B3']
# ['UNCA'] ['UDCA']
# ['33', '00'] ['OG', '33']
# ['HN'] ['HM']
# ['5'] ['15']
# ['AM'] ['AMG']
# ['20', 'JY'] ['JY', '20']
# ['-'] ['|']
# ['|'] ['D']
# ['15'] ['C|N2']
# ['140'] ['G40']
# ['|'] ['JY']
# ['|'] ['150']
# ['|M'] ['B|M']
# ['|'] ['CICOR']
# ['JN'] ['jw']
# ['|'] ['D5']
# ['5D'] ['S1']
# ['|'] ['016']
# ['B|80'] ['G|80']
# ['DX)'] ['DX']
# ['ANA', '50'] ['ANT', '50']
# ['A4'] ['AZ']
# ['|'] ['SL8']
# ['RS', 'JY'] ['JY', 'RS']
# ['50)'] ['50']
# ['-', 'TG', 'AD'] ['AD', 'TG', '-']
# ['ANA27'] ['ANA275']
# ['JN'] ['jw']
# ['KD'] ['CKD']
# ['|'] ['D.W']
# ['|'] ['CICOR']
# ['000'] ['1000']
# ['|'] ['G|80']
# ['|N2'] ['C|N2']
# ['-'] ['SR']
# ['|'] ['CICOR']
# ['DXD'] ['DX']
# ['|'] ['20']
# ['S)'] ['D|S']
# ['CCCOR'] ['CICOR']
# ['275)'] ['ANA275']
# ['|'] ['T']
# ['|'] ['75']
# ['|'] ['1000']
# ['Y|CU'] ['G|80']
# ['|'] ['SK']
# ['|'] ['FH|6']
# ['|'] ['JTA']
# ['|', '|'] ['RS', 'JY']
# ['A', 'CGL'] ['A', 'CG']
# ['B'] ['FB']
# ['D'] ['012']
# ['80'] ['G|80']
# ['|'] ['JY']
# ['J'] ['JY']
# ['|'] ['T|R']
# ['50', '|'] ['ANT', '50']
# ['FA|', 'CH'] ['A', 'CH']
# ['|UNITED'] ['UNITED']
# ['M|'] ['B|M']
# ['|'] ['T']
# ['|'] ['Y|H']
# ['|'] ['JY']
# ['S501'] ['S50']
# ['|'] ['C|M']
# ['-'] ['AV']
# ['CKD-'] ['CKD']
# ['|'] ['JI']
# ['15'] ['75']
# ['|'] ['ANA275']
# ['J|8'] ['G|80']
# ['|'] ['5010']
# ['|'] ['B|M']
# ['AZ|'] ['AZ']
# ['140'] ['G40']
# ['|'] ['750']
# ['|'] ['R5']
# ['N|'] ['C|NI']
# ['G4C'] ['G40']
# ['||M'] ['B|M']
# ['B|6'] ['B|K']
# ['||'] ['|']
# ['CNL'] ['C|NI']
# ['S'] ['S1']
# ['|'] ['Noltec10']
# ['1:'] ['75']
# ['A', 'CHZ'] ['A', 'CH']
# ['(BK'] ['BK']
# ['|'] ['B|K']
# ['|'] ['JI']
# ['(5'] ['75']
# ['5'] ['S']
# ['|'] ['S']
# ['E|N'] ['C|NI']
# ['Y|'] ['PC']
# ['D|S)'] ['D|S']
# ['SEARLE', '30'] ['SEARLE', '39']
# ['D|'] ['D|5']
# ['JJ'] ['DG']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['-'] ['GDOR']
# ['|'] ['SK']
# ['|'] ['Cossac-L']
# ['NI'] ['C|NI']
# ['C'] ['SR']
# ['K'] ['SK']
# ['S|'] ['D|S']
# ['|'] ['FH|6']
# ['CG', 'A'] ['A', 'CG']
# ['CICORT'] ['CICOR']
# ['V'] ['LV']
# ['JY', 'RS'] ['RS', 'JY']
# ['T5'] ['MTS']
# ['N'] ['NVR']
# ['|'] ['H|3']
# ['50)'] ['50']
# ['H'] ['Y|H']
# ['39|', 'HARLE'] ['SEARLE', '39']
# ['CG', 'A'] ['A', 'CG']
# ['CKDY'] ['CKD']
# ['|'] ['016']
# ['LJ'] ['20']
# ['RS', 'JY'] ['JY', 'RS']
# ['4'] ['AZ']
# ['G|'] ['A|G']
# ['-'] ['GDOR']
# ['|'] ['CD']
# ['18'] ['018']
# ['|'] ['T']
# ['|'] ['CG']
# ['A|'] ['NL']
# ['|'] ['2510']
# ['|'] ['SK']
# ['|'] ['1000']
# ['|'] ['JY']
# ['C4'] ['T4']
# ['KHL', '02V'] ['KH', '021']
# ['DC'] ['PC']
# ['|M'] ['B|M']
# ['C4'] ['T4']
# ['Y|'] ['ry']
# ['J'] ['JY']
# ['CC'] ['CKD']
# ['RS', 'JY'] ['JY', 'RS']
# ['-V'] ['AV']
# ['|'] ['T|R']
# ['A4'] ['CICOR']
# ['4|3'] ['H|3']
# ['5'] ['R5']
# ['|'] ['1']
# ['H)'] ['Y|H']
# ['FE7', '|'] ['GS', 'FE7']
# ['J'] ['JY']
# ['|'] ['FH|6']
# ['JY', 'RS'] ['RS', 'JY']
# ['|4'] ['T4']
# ['A', 'CGL'] ['A', 'CG']
# ['1'] ['D5']
# ['S'] ['SR']
# ['|'] ['AV']
# ['|'] ['T']
# ['-'] ['GDOR']
# ['|'] ['T']
# ['RS', 'JY'] ['JY', 'RS']
# ['KH', '0HL'] ['KH', '021']
# ['5'] ['D|5']
# ['|'] ['CICOR']
# ['014'] ['012']
# ['|'] ['JY']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|'] ['PC']
# ['(Hanmi'] ['Hanmi']
# ['-', 'AD', 'TG'] ['TG', 'AD', '-']
# ['|'] ['AV']
# ['|'] ['LV']
# ['C'] ['C|NI']
# ['5'] ['5050']
# ['CNX', '50'] ['ANT', '50']
# ['|'] ['S50']
# ['H|S'] ['G|80']
# ['YG'] ['FB']
# ['|J'] ['J|Y']
# ['|'] ['D']
# ['|'] ['S1']
# ['|'] ['10']
# ['RS', 'JY'] ['JY', 'RS']
# ['RS', 'JY'] ['JY', 'RS']
# ['C'] ['SR']
# ['DOR'] ['GDOR']
# ['|'] ['GDOR']
# ['DD'] ['D']
# ['DU'] ['DG']
# ['JN'] ['jw']
# ['KK'] ['BK']
# ['B1'] ['B|M']
# ['S|'] ['D|S']
# ['|5'] ['D|5']
# ['20', 'JY'] ['JY', '20']
# ['(K'] ['BK']
# ['-'] ['750']
# ['A', 'CHZ'] ['A', 'CH']
# ['|'] ['T']
# ['Naxozol', '500/2'] ['Naxozol', '500/20']
# ['DXD'] ['DX']
# ['|'] ['SR']
# ['CK'] ['CKD']
# ['SEARLE', '30'] ['SEARLE', '39']
# ['JV'] ['jw']
# ['50%'] ['50']
# ['5'] ['D']
# ['GDOR'] ['GDOP']
# ['-'] ['500']
# ['|'] ['20']
# ['|'] ['D.W']
# ['-'] ['D5']
# ['|', '|'] ['KH', '021']
# ['|'] ['G|80']
# ['|NY'] ['C|NI']
# ['-'] ['20']
# ['GOF'] ['G|80']
# ['|'] ['C200']
# ['50'] ['750']
# ['AD', '-', 'TG'] ['AD', 'TG', '-']
# ['SEARLE', '30'] ['SEARLE', '39']
# ['R'] ['Y|H']
# ['G|8'] ['G|80']
# ['|'] ['S']
# ['|'] ['JY']
# ['CH', 'A'] ['A', 'CH']
# ['W'] ['D.W']
# ['CD'] ['|']
# ['|'] ['H|3']
# ['J'] ['LV']
# ['0', '|'] ['G', '50']
# ['-'] ['500']
# ['OSSAC-L'] ['Cossac-L']
# ['JG'] ['CG']
# ['H|S'] ['H|3']
# ['B1'] ['81']
# ['R'] ['81']
# ['JA'] ['75']
# ['0/20', 'XOZOl'] ['Naxozol', '500/20']
# ['SEARLE', '38'] ['SEARLE', '39']
# ['|NI'] ['C|NI']
# ['|'] ['H|3']
# ['588'] ['G|80']
# ['20', 'JY'] ['JY', '20']
# ['AZ|'] ['AZ']
# ['N1'] ['C|NI']
# ['4'] ['J25']
# ['|'] ['B|M']
# ['|'] ['JY']
# ['X'] ['DX']
# ['|'] ['D']
# ['-', '-'] ['5', 'BD']
# ['5|M'] ['C|M']
# ['154'] ['750']
# ['d0', '|'] ['A', 'CG']
# ['588'] ['G|80']
# ['|'] ['JY']
# ['30', 'CLARLE'] ['SEARLE', '39']
# ['H|'] ['H|3']
# ['|'] ['10']
# ['J4'] ['J25']
# ['H|'] ['|']
# ['|'] ['SR']
# ['|'] ['UT']
# ['Naxoz', '500/'] ['500/20', 'Naxozol']
# ['L'] ['NL']
# ['RS', 'S1'] ['RS', 'JY']
# ['MA|RYL'] ['AMA|RYL']
# ['JZ'] ['AZ']
# ['|'] ['T']
# ['5'] ['S']
# ['|'] ['A|M']
# ['|'] ['JI']
# ['G180'] ['G|80']
# ['|', 'SEARLE'] ['SEARLE', '39']
# ['-'] ['BK']
# ['|'] ['JY']
# ['|'] ['B|M']
# ['50', '|N'] ['ANT', '50']
# ['5'] ['FH|6']
# ['|'] ['GDOR']
# ['|'] ['AV']
# ['|H'] ['|']
# ['DUF'] ['G|80']
# ['D.V'] ['D.W']
# ['500/20', '|'] ['500/20', 'Naxozol']
# ['-'] ['SK']
# ['|'] ['SR']
# ['RS', '|'] ['JY', 'RS']
# ['|'] ['UT']
# ['-'] ['GDOR']
# ['TA'] ['JTA']
# ['|'] ['JI']
# ['ANA2'] ['ANA275']
# ['|'] ['GDOR']
# ['K'] ['SK']
# ['B'] ['B|K']
# ['-', 'TG', 'AD'] ['TG', 'AD', '-']
# ['|'] ['G|80']
# ['|'] ['JI']
# ['|'] ['SK']
# ['|', 'EARL'] ['SEARLE', '39']
# ['|'] ['Cossac-L']
# ['|'] ['018']
# ['40', '|'] ['20', 'JY']
# ['DD'] ['D']
# ['NA2750'] ['ANA275']
# ['|5'] ['R5']
# ['RS', 'JY'] ['JY', 'RS']
# ['6'] ['FH|6']
# ['|'] ['SR']
# ['10'] ['G40']
# ['01'] ['81']
# ['DC'] ['DG']
# ['Naxozo', '500/20'] ['Naxozol', '500/20']
# ['|'] ['S']
# ['|'] ['H|3']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|'] ['Y|H']
# ['|'] ['CD']
# ['J|'] ['JY']
# ['|'] ['T']
# ['20', 'JY'] ['JY', '20']
# ['|N', '50'] ['ANT', '50']
# ['1'] ['T']
# ['|'] ['D']
# ['KH', '02V'] ['KH', '021']
# ['|'] ['Noltec10']
# ['RS', 'JY'] ['JY', 'RS']
# ['DUU'] ['500']
# ['J|'] ['2510']
# ['5)'] ['75']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|'] ['H|3']
# ['CG', 'AX'] ['A', 'CG']
# ['1'] ['T']
# ['(1'] ['BK']
# ['JH'] ['OMP']
# ['|'] ['HGH']
# ['JK'] ['SK']
# ['|'] ['1']
# ['4'] ['2']
# ['|'] ['D.W']
# ['FE7', 'GS'] ['GS', 'FE7']
# ['|N2'] ['C|N2']
# ['oltec10'] ['Noltec10']
# ['R|G'] ['FH|6']
# ['NL', '5'] ['CNL', '5']
# ['HW'] ['D-W']
# ['K|'] ['B|K']
# ['016'] ['012']
# ['(BK)'] ['BK']
# ['|'] ['Y|H']
# ['|S'] ['|']
# ['|'] ['SK']
# ['JN'] ['jw']
# ['|5'] ['MTS']
# ['G80'] ['G|80']
# ['J4'] ['T4']
# ['H)'] ['Y|H']
# ['|'] ['SL8']
# ['L'] ['NL']
# ['20', 'JY'] ['JY', '20']
# ['|'] ['JI']
# ['|'] ['SK']
# ['V'] ['AV']
# ['U1'] ['JI']
# ['(DG'] ['DG']
# ['D1'] ['D']
# ['J'] ['JI']
# ['20', 'JY'] ['JY', '20']
# ['(016'] ['016']
# ['505'] ['5050']
# ['-'] ['750']
# ['50|'] ['150']
# ['|'] ['JY']
# ['|'] ['S']
# ['1252'] ['125']
# ['39', 'HARLR'] ['SEARLE', '39']
# ['|'] ['H|L']
# ['CXL', '4'] ['4', 'CXL']
# ['RN>', '50'] ['ANT', '50']
# ['J|'] ['J|Y']
# ['|'] ['C']
# ['|44'] ['T4']
# ['15'] ['75']
# ['|'] ['A|M']
# ['5'] ['75']
# ['|'] ['S1']
# ['C', '50'] ['G', '50']
# ['r'] ['D']
# ['3K'] ['BK']
# ['|'] ['D-W']
# ['|'] ['T']
# ['H'] ['PC']
# ['-'] ['1000']
# ['1015'] ['015']
# ['|'] ['2']
# ['-'] ['JTA']
# ['R'] ['SR']
# ['|'] ['10']
# ['HTS'] ['MTS']
# ['NT'] ['NVR']
# ['R|'] ['SR']
# ['|'] ['A|M']
# ['|'] ['D|5']
# ['|'] ['JY']
# ['15'] ['75']
# ['|'] ['JY']
# ['CG', '|'] ['A', 'CG']
# ['RS'] ['R5']
# ['IOL'] ['125']
# ['-'] ['5010']
# ['|'] ['JY']
# ['D,'] ['D.W']
# ['NA275'] ['ANA275']
# ['4'] ['2']
# ['AD', '-', 'TG'] ['AD', 'TG', '-']
# ['XN>', '50'] ['ANT', '50']
# ['|'] ['D']
# ['|'] ['5010']
# ['jUT'] ['GDOR']
# ['|'] ['JY']
# ['H|'] ['B|M']
# ['C|2'] ['C|N2']
# ['-', 'TG', 'AD'] ['AD', 'TG', '-']
# ['0|'] ['150']
# ['550'] ['S50']
# ['HEARLH', '30'] ['SEARLE', '39']
# ['G'] ['D5']
# ['|'] ['JY']
# ['|'] ['NVR']
# ['994'] ['952']
# ['L'] ['LV']
# ['J|L'] ['JY']
# ['tec10'] ['Noltec10']
# ['H||'] ['B|M']
# ['|-'] ['A|G']
# ['>|N5'] ['C|N2']
# ['|'] ['B|M']
# ['|'] ['JY']
# ['JW'] ['D-W']
# ['10'] ['G40']
# ['|'] ['S1']
# ['RS', 'JY'] ['JY', 'RS']
# ['BD', '5'] ['5', 'BD']
# ['|'] ['2']
# ['|1'] ['S']
# ['|'] ['D']
# ['UV'] ['D-W']
# ['50', 'D'] ['G', '50']
# ['-'] ['MTS']
# ['|'] ['CICOR']
# ['|M'] ['B|M']
# ['|'] ['B|K']
# ['-', 'AD', 'TG'] ['TG', 'AD', '-']
# ['50', '|N'] ['ANT', '50']
# ['|K'] ['SK']
# ['4', 'J'] ['CXL', '4']
# ['C|S'] ['X|S']
# ['B'] ['FB']
# ['Cw'] ['D.W']
# ['C4'] ['T4']
# ['|'] ['2510']
# ['|'] ['Noltec10']

# %%
f = open("custom_source.txt", 'w')
ft = open("custom_target.txt", 'w')
for pred, gt in zip(pred_list, gt_list):
    if(len(pred) != len(gt)):
        continue
    else:
        for p, g in zip(pred,gt):
            if(len(p)==len(g)):
                print(p,g)
                f.write(p+"\n")
                ft.write(g+'\n')
# Out:
# Airtal Alrtal
# HL300 EL300
# Airtal Alrtal
# HL300 EL300
# ANG AMG
# MMG AMG
# ACIOS ACTOS
# YH JY
# r T
# FEI FET
# SK SK
# TH HM
# JYM JYP
# HN HM
# 1G 16
# ME7 MET
# HRR HTR
# HS ES
# HIR HTR
# Z5 ZS
# J2M JYP
# FRT FET
# SK SK
# HL300 EL300
# Airtal Alrtal
# JYR JYP
# HL300 EL300
# AM8 AMG
# Airtal Alrtal
# ATL ATV
# HIR HTR
# ATY ATV
# HIR HTR
# HL300 EL300
# |25 J25
# 80 30
# FHI FET
# 5K SK
# Airtal Alrtal
# Z5 ZS
# B|W D|W
# JYR JYP
# H5 ES
# CX JY
# JY CX
# Z5 ZS
# DG OG
# 33 33
# BS ES
# 5K SK
# FET FET
# HS ES
# ATI ATV
# LWG AMG
# 55 ES
# RN> ANT
# 50 50
# B5 ES
# | T
# 15 16
# 33 OG
# DG 33
# HL300 EL300
# ME1 MET
# 00 OG
# 38 33
# HL300 EL300
# 00 OG
# 33 33
# | T
# |Y YH
# 33 OG
# 00 33
# DS OG
# 33 33
# 80 30
# HIR HTR
# 1G 16
# YH JY
# Airtal Alrtal
# r T
# 1 T
# r T
# JYL JYP
# (JY JYP
# 80 30
# D-W D-W
# J1 JY
# ATY ATV
# HJR HTR
# ACT05 ACTOS
# YH JY
# BM BM
# UNCA UDCA
# 33 OG
# 00 33
# HN HM
# 20 JY
# JY 20
# - |
# | D
# 140 G40
# JN jw
# 5D S1
# B|80 G|80
# ANA ANT
# 50 50
# A4 AZ
# RS JY
# JY RS
# TG TG
# JN jw
# CCCOR CICOR
# | T
# Y|CU G|80
# A A
# CH CH
# | T
# 15 75
# 140 G40
# G4C G40
# ||M B|M
# B|6 B|K
# 1: 75
# A A
# (5 75
# 5 S
# | S
# Y| PC
# SEARLE SEARLE
# 30 39
# JJ DG
# JY RS
# RS JY
# LJ 20
# RS JY
# JY RS
# | T
# A| NL
# C4 T4
# 02V 021
# DC PC
# C4 T4
# Y| ry
# RS JY
# JY RS
# -V AV
# 4|3 H|3
# | 1
# JY RS
# RS JY
# |4 T4
# A A
# | T
# | T
# RS JY
# JY RS
# KH KH
# 0HL 021
# 014 012
# AD AD
# CNX ANT
# 50 50
# YG FB
# | D
# RS JY
# JY RS
# RS JY
# JY RS
# DU DG
# JN jw
# KK BK
# 20 JY
# JY 20
# (K BK
# A A
# | T
# Naxozol Naxozol
# SEARLE SEARLE
# 30 39
# JV jw
# 5 D
# GDOR GDOP
# AD AD
# SEARLE SEARLE
# 30 39
# | S
# 0 G
# JG CG
# H|S H|3
# B1 81
# JA 75
# SEARLE SEARLE
# 38 39
# 20 JY
# JY 20
# | D
# - 5
# 5|M C|M
# 154 750
# RS RS
# S1 JY
# JZ AZ
# | T
# 5 S
# G180 G|80
# |N 50
# D.V D.W
# 500/20 500/20
# RS JY
# TG AD
# 40 20
# NA2750 ANA275
# |5 R5
# RS JY
# JY RS
# 01 81
# DC DG
# 500/20 500/20
# | S
# J| JY
# | T
# 20 JY
# JY 20
# 50 50
# 1 T
# | D
# KH KH
# 02V 021
# RS JY
# JY RS
# DUU 500
# 5) 75
# AX CG
# 1 T
# (1 BK
# JK SK
# | 1
# 4 2
# 5 5
# 016 012
# JN jw
# J4 T4
# 20 JY
# JY 20
# U1 JI
# 20 JY
# JY 20
# 50| 150
# | S
# RN> ANT
# 50 50
# | C
# 15 75
# C G
# 50 50
# r D
# 3K BK
# | T
# | 2
# HTS MTS
# R| SR
# 15 75
# RS R5
# IOL 125
# 4 2
# AD AD
# XN> ANT
# 50 50
# | D
# TG TG
# 550 S50
# HEARLH SEARLE
# 30 39
# 994 952
# H|| B|M
# >|N5 C|N2
# RS JY
# JY RS
# | 2
# | D
# AD AD
# |N 50
# |K SK
# J 4
# C|S X|S
# C4 T4
